# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torchvision
from torchvision import models, transforms, datasets
#import helper

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
                                      ])

valid_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
                                      ])

test_transforms = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
                                     ])

# %%
# TODO: Load the datasets with ImageFolder
train_datasets = datasets.ImageFolder(train_dir, transform =train_transforms)
valid_datasets = datasets.ImageFolder(valid_dir, transform =valid_transforms)
test_datasets = datasets.ImageFolder(test_dir, transform =test_transforms)

# %%
# TODO: Using the image datasets and the trainforms, define the dataloaders
traindataloader = torch.utils.data.DataLoader(train_datasets, batch_size= 64, shuffle = True)
validdataloader = torch.utils.data.DataLoader(valid_datasets, batch_size= 64)
testdataloader = torch.utils.data.DataLoader(test_datasets, batch_size= 64)

# %%
# Run this to test your data loader
images, labels = next(iter(traindataloader))
print(images.shape, labels.shape, images.type)
# Out:
# torch.Size([64, 3, 224, 224]) torch.Size([64]) <built-in method type of Tensor object at 0x7f304ea11048>

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json
        
def class_to_idx():
    # category label to category name mapping
    with open('cat_to_name.json', 'r') as f:
        cat_to_name_dic = json.load(f)
    return cat_to_name_dic

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# <font color='red'>**Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.</font>

# %%
# TODO: Build and train your network
model= models.vgg16(pretrained = True)
model.classifier.state_dict
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:05<00:00, 105620031.27it/s]
# <bound method Module.state_dict of Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace)
#   (2): Dropout(p=0.5)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace)
#   (5): Dropout(p=0.5)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )>

# %%
# set parameters
arch = 'vgg'
h_layer = 4096
lr = 0.001
gpu = True
epochs = 20

# use GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

#freeze parameters and update classifier
for param in model.parameters():
    param.requires_grad = False

classifier = nn.Sequential(nn.Linear(25088, h_layer),
                           nn.ReLU(),
                           nn.Dropout(0.5),
                           nn.Linear(h_layer, h_layer),
                           nn.ReLU(),
                           nn.Dropout(0.5),
                           nn.Linear(h_layer, 102),
                           nn.LogSoftmax(dim=1))
    
model.classifier = classifier

criterion = nn.NLLLoss()

# Only train the classifier parameters, feature parameters are frozen
optimizer = optim.Adam(model.classifier.parameters(), lr=lr)

model.to(device);
model.classifier.state_dict
# Out:
# <bound method Module.state_dict of Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.5)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.5)
#   (6): Linear(in_features=4096, out_features=102, bias=True)
#   (7): LogSoftmax()
# )>

# %%
# training the model
epochs = 20
steps = 0
running_loss = 0
print_every = 5

from workspace_utils import active_session
with active_session():
    # do long-running work here
    for epoch in range(epochs):
        for inputs, labels in traindataloader:
            steps += 1
            # Move input and label tensors to the default device
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()

            logps = model.forward(inputs)  # forward path
            loss = criterion(logps, labels)  # calculate loss 
            loss.backward()         # backpropagation , auto grade: propagate back loss to obtain weights (w_dash)
            optimizer.step()         # calculate new weights according to learning rate(w_new)

            running_loss += loss.item()

            if steps % print_every == 0:
                valid_loss = 0
                accuracy = 0
                model.eval()    # stop drop out evaluate all weights
                with torch.no_grad():   # no need for optimizer so stop autograde
                    for inputs, labels in validdataloader:
                        inputs, labels = inputs.to(device), labels.to(device)
                        logps = model.forward(inputs)
                        batch_loss = criterion(logps, labels)

                        valid_loss += batch_loss.item()

                        # Calculate accuracy
                        ps = torch.exp(logps)  # turn model output into probabilities
                        top_p, top_class = ps.topk(1, dim=1)   # find first top prob and it's equivelant top class
                        equals = top_class == labels.view(*top_class.shape)  #if top_class == labels ,let equals=1
                        accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

                print(f"Epoch {epoch+1}/{epochs}.. "
                      f"Train loss: {running_loss/print_every:.3f}.. "
                      f"valid loss: {valid_loss/len(validdataloader):.3f}.. "
                      f"valid accuracy: {accuracy/len(validdataloader):.3f}")
                running_loss = 0
                model.train()
# Out:
# Epoch 1/20.. Train loss: 7.225.. valid loss: 5.146.. valid accuracy: 0.011
# Epoch 1/20.. Train loss: 4.741.. valid loss: 4.398.. valid accuracy: 0.103
# Epoch 1/20.. Train loss: 4.463.. valid loss: 4.187.. valid accuracy: 0.124
# Epoch 1/20.. Train loss: 4.236.. valid loss: 3.872.. valid accuracy: 0.180
# Epoch 1/20.. Train loss: 3.981.. valid loss: 3.549.. valid accuracy: 0.196
# Epoch 1/20.. Train loss: 3.783.. valid loss: 3.305.. valid accuracy: 0.283
# Epoch 1/20.. Train loss: 3.588.. valid loss: 2.955.. valid accuracy: 0.322
# Epoch 1/20.. Train loss: 3.446.. valid loss: 2.777.. valid accuracy: 0.352
# Epoch 1/20.. Train loss: 3.157.. valid loss: 2.484.. valid accuracy: 0.403
# Epoch 1/20.. Train loss: 3.121.. valid loss: 2.266.. valid accuracy: 0.452
# Epoch 1/20.. Train loss: 2.902.. valid loss: 2.326.. valid accuracy: 0.423
# Epoch 1/20.. Train loss: 2.905.. valid loss: 1.920.. valid accuracy: 0.511
# Epoch 1/20.. Train loss: 2.689.. valid loss: 1.947.. valid accuracy: 0.502
# Epoch 1/20.. Train loss: 2.514.. valid loss: 1.712.. valid accuracy: 0.553
# Epoch 1/20.. Train loss: 2.587.. valid loss: 1.682.. valid accuracy: 0.546
# Epoch 1/20.. Train loss: 2.561.. valid loss: 1.805.. valid accuracy: 0.536
# Epoch 1/20.. Train loss: 2.747.. valid loss: 1.619.. valid accuracy: 0.570
# Epoch 1/20.. Train loss: 2.685.. valid loss: 1.496.. valid accuracy: 0.622
# Epoch 1/20.. Train loss: 2.554.. valid loss: 1.523.. valid accuracy: 0.597
# Epoch 1/20.. Train loss: 2.448.. valid loss: 1.498.. valid accuracy: 0.636
# Epoch 2/20.. Train loss: 2.348.. valid loss: 1.548.. valid accuracy: 0.594
# Epoch 2/20.. Train loss: 2.521.. valid loss: 1.542.. valid accuracy: 0.602
# Epoch 2/20.. Train loss: 2.369.. valid loss: 1.472.. valid accuracy: 0.605
# Epoch 2/20.. Train loss: 2.293.. valid loss: 1.344.. valid accuracy: 0.634
# Epoch 2/20.. Train loss: 2.371.. valid loss: 1.350.. valid accuracy: 0.617
# Epoch 2/20.. Train loss: 2.266.. valid loss: 1.407.. valid accuracy: 0.626
# Epoch 2/20.. Train loss: 2.464.. valid loss: 1.269.. valid accuracy: 0.655
# Epoch 2/20.. Train loss: 2.255.. valid loss: 1.324.. valid accuracy: 0.642
# Epoch 2/20.. Train loss: 2.374.. valid loss: 1.372.. valid accuracy: 0.620
# Epoch 2/20.. Train loss: 2.505.. valid loss: 1.361.. valid accuracy: 0.630
# Epoch 2/20.. Train loss: 2.445.. valid loss: 1.329.. valid accuracy: 0.643
# Epoch 2/20.. Train loss: 2.344.. valid loss: 1.263.. valid accuracy: 0.665
# Epoch 2/20.. Train loss: 2.087.. valid loss: 1.231.. valid accuracy: 0.680
# Epoch 2/20.. Train loss: 2.123.. valid loss: 1.317.. valid accuracy: 0.655
# Epoch 2/20.. Train loss: 2.399.. valid loss: 1.260.. valid accuracy: 0.667
# Epoch 2/20.. Train loss: 2.097.. valid loss: 1.205.. valid accuracy: 0.684
# Epoch 2/20.. Train loss: 2.288.. valid loss: 1.077.. valid accuracy: 0.710
# Epoch 2/20.. Train loss: 2.311.. valid loss: 1.038.. valid accuracy: 0.719
# Epoch 2/20.. Train loss: 2.358.. valid loss: 1.058.. valid accuracy: 0.715
# Epoch 2/20.. Train loss: 2.140.. valid loss: 1.132.. valid accuracy: 0.700
# Epoch 2/20.. Train loss: 2.149.. valid loss: 1.149.. valid accuracy: 0.701
# Epoch 3/20.. Train loss: 2.176.. valid loss: 1.263.. valid accuracy: 0.670
# Epoch 3/20.. Train loss: 2.290.. valid loss: 1.229.. valid accuracy: 0.682
# Epoch 3/20.. Train loss: 2.250.. valid loss: 1.111.. valid accuracy: 0.705
# Epoch 3/20.. Train loss: 2.292.. valid loss: 1.211.. valid accuracy: 0.662
# Epoch 3/20.. Train loss: 2.143.. valid loss: 1.088.. valid accuracy: 0.700
# Epoch 3/20.. Train loss: 2.131.. valid loss: 1.016.. valid accuracy: 0.736
# Epoch 3/20.. Train loss: 2.186.. valid loss: 1.069.. valid accuracy: 0.720
# Epoch 3/20.. Train loss: 2.178.. valid loss: 1.095.. valid accuracy: 0.716
# Epoch 3/20.. Train loss: 2.107.. valid loss: 1.047.. valid accuracy: 0.707
# Epoch 3/20.. Train loss: 1.956.. valid loss: 1.055.. valid accuracy: 0.721
# Epoch 3/20.. Train loss: 2.218.. valid loss: 1.002.. valid accuracy: 0.734
# Epoch 3/20.. Train loss: 2.093.. valid loss: 1.008.. valid accuracy: 0.733
# Epoch 3/20.. Train loss: 1.809.. valid loss: 1.044.. valid accuracy: 0.707
# Epoch 3/20.. Train loss: 2.345.. valid loss: 1.043.. valid accuracy: 0.721
# Epoch 3/20.. Train loss: 2.077.. valid loss: 1.071.. valid accuracy: 0.717
# Epoch 3/20.. Train loss: 2.024.. valid loss: 0.992.. valid accuracy: 0.743
# Epoch 3/20.. Train loss: 2.152.. valid loss: 0.918.. valid accuracy: 0.755
# Epoch 3/20.. Train loss: 1.899.. valid loss: 0.913.. valid accuracy: 0.752
# Epoch 3/20.. Train loss: 2.091.. valid loss: 0.925.. valid accuracy: 0.759
# Epoch 3/20.. Train loss: 1.953.. valid loss: 0.928.. valid accuracy: 0.756
# Epoch 4/20.. Train loss: 2.135.. valid loss: 0.980.. valid accuracy: 0.731
# Epoch 4/20.. Train loss: 1.888.. valid loss: 1.055.. valid accuracy: 0.710
# Epoch 4/20.. Train loss: 2.278.. valid loss: 1.036.. valid accuracy: 0.722
# Epoch 4/20.. Train loss: 2.224.. valid loss: 0.934.. valid accuracy: 0.752
# Epoch 4/20.. Train loss: 2.129.. valid loss: 0.936.. valid accuracy: 0.754
# Epoch 4/20.. Train loss: 2.180.. valid loss: 0.920.. valid accuracy: 0.758
# Epoch 4/20.. Train loss: 2.002.. valid loss: 0.954.. valid accuracy: 0.743
# Epoch 4/20.. Train loss: 1.864.. valid loss: 0.977.. valid accuracy: 0.740
# Epoch 4/20.. Train loss: 2.009.. valid loss: 1.019.. valid accuracy: 0.716
# Epoch 4/20.. Train loss: 2.216.. valid loss: 0.989.. valid accuracy: 0.732
# Epoch 4/20.. Train loss: 2.123.. valid loss: 0.980.. valid accuracy: 0.741
# Epoch 4/20.. Train loss: 1.992.. valid loss: 1.003.. valid accuracy: 0.718
# Epoch 4/20.. Train loss: 1.818.. valid loss: 1.022.. valid accuracy: 0.726
# Epoch 4/20.. Train loss: 2.191.. valid loss: 0.932.. valid accuracy: 0.753
# Epoch 4/20.. Train loss: 2.009.. valid loss: 0.885.. valid accuracy: 0.776
# Epoch 4/20.. Train loss: 2.100.. valid loss: 0.887.. valid accuracy: 0.781
# Epoch 4/20.. Train loss: 2.069.. valid loss: 0.937.. valid accuracy: 0.748
# Epoch 4/20.. Train loss: 2.104.. valid loss: 0.955.. valid accuracy: 0.740
# Epoch 4/20.. Train loss: 1.954.. valid loss: 0.922.. valid accuracy: 0.745
# Epoch 4/20.. Train loss: 1.838.. valid loss: 0.903.. valid accuracy: 0.759
# Epoch 4/20.. Train loss: 2.034.. valid loss: 0.929.. valid accuracy: 0.745
# Epoch 5/20.. Train loss: 2.014.. valid loss: 0.911.. valid accuracy: 0.765
# Epoch 5/20.. Train loss: 2.096.. valid loss: 0.868.. valid accuracy: 0.774
# Epoch 5/20.. Train loss: 1.913.. valid loss: 0.870.. valid accuracy: 0.770
# Epoch 5/20.. Train loss: 1.980.. valid loss: 0.875.. valid accuracy: 0.761
# Epoch 5/20.. Train loss: 1.899.. valid loss: 0.885.. valid accuracy: 0.767
# Epoch 5/20.. Train loss: 2.155.. valid loss: 0.896.. valid accuracy: 0.772
# Epoch 5/20.. Train loss: 2.009.. valid loss: 0.932.. valid accuracy: 0.757
# Epoch 5/20.. Train loss: 2.084.. valid loss: 0.949.. valid accuracy: 0.755
# Epoch 5/20.. Train loss: 1.952.. valid loss: 0.942.. valid accuracy: 0.755
# Epoch 5/20.. Train loss: 1.760.. valid loss: 0.911.. valid accuracy: 0.769
# Epoch 5/20.. Train loss: 2.071.. valid loss: 0.952.. valid accuracy: 0.743
# Epoch 5/20.. Train loss: 2.075.. valid loss: 0.930.. valid accuracy: 0.764
# Epoch 5/20.. Train loss: 2.237.. valid loss: 0.921.. valid accuracy: 0.762
# Epoch 5/20.. Train loss: 2.199.. valid loss: 0.898.. valid accuracy: 0.775
# Epoch 5/20.. Train loss: 2.076.. valid loss: 0.949.. valid accuracy: 0.741
# Epoch 5/20.. Train loss: 1.862.. valid loss: 0.903.. valid accuracy: 0.769
# Epoch 5/20.. Train loss: 1.932.. valid loss: 0.865.. valid accuracy: 0.772
# Epoch 5/20.. Train loss: 2.044.. valid loss: 0.909.. valid accuracy: 0.756
# Epoch 5/20.. Train loss: 2.041.. valid loss: 0.907.. valid accuracy: 0.771
# Epoch 5/20.. Train loss: 1.957.. valid loss: 0.854.. valid accuracy: 0.794
# Epoch 5/20.. Train loss: 1.860.. valid loss: 0.851.. valid accuracy: 0.798
# Epoch 6/20.. Train loss: 2.153.. valid loss: 0.936.. valid accuracy: 0.766
# Epoch 6/20.. Train loss: 2.014.. valid loss: 0.936.. valid accuracy: 0.770
# Epoch 6/20.. Train loss: 1.877.. valid loss: 0.909.. valid accuracy: 0.760
# Epoch 6/20.. Train loss: 2.114.. valid loss: 0.904.. valid accuracy: 0.781
# Epoch 6/20.. Train loss: 2.034.. valid loss: 0.952.. valid accuracy: 0.768
# Epoch 6/20.. Train loss: 1.939.. valid loss: 0.854.. valid accuracy: 0.790
# Epoch 6/20.. Train loss: 1.935.. valid loss: 0.863.. valid accuracy: 0.796
# Epoch 6/20.. Train loss: 1.994.. valid loss: 0.891.. valid accuracy: 0.788
# Epoch 6/20.. Train loss: 2.114.. valid loss: 0.886.. valid accuracy: 0.786
# Epoch 6/20.. Train loss: 2.039.. valid loss: 0.873.. valid accuracy: 0.795
# Epoch 6/20.. Train loss: 2.106.. valid loss: 0.878.. valid accuracy: 0.783
# Epoch 6/20.. Train loss: 2.021.. valid loss: 0.830.. valid accuracy: 0.809
# Epoch 6/20.. Train loss: 1.741.. valid loss: 0.813.. valid accuracy: 0.813
# Epoch 6/20.. Train loss: 2.119.. valid loss: 0.798.. valid accuracy: 0.804
# Epoch 6/20.. Train loss: 1.866.. valid loss: 0.820.. valid accuracy: 0.791
# Epoch 6/20.. Train loss: 1.902.. valid loss: 0.844.. valid accuracy: 0.780
# Epoch 6/20.. Train loss: 2.168.. valid loss: 0.804.. valid accuracy: 0.799
# Epoch 6/20.. Train loss: 1.895.. valid loss: 0.780.. valid accuracy: 0.814
# Epoch 6/20.. Train loss: 2.162.. valid loss: 0.762.. valid accuracy: 0.821
# Epoch 6/20.. Train loss: 1.950.. valid loss: 0.766.. valid accuracy: 0.803
# Epoch 7/20.. Train loss: 1.870.. valid loss: 0.800.. valid accuracy: 0.810
# Epoch 7/20.. Train loss: 1.947.. valid loss: 0.858.. valid accuracy: 0.791
# Epoch 7/20.. Train loss: 1.667.. valid loss: 0.865.. valid accuracy: 0.781
# Epoch 7/20.. Train loss: 1.846.. valid loss: 0.824.. valid accuracy: 0.804
# Epoch 7/20.. Train loss: 1.670.. valid loss: 0.847.. valid accuracy: 0.799
# Epoch 7/20.. Train loss: 1.784.. valid loss: 0.825.. valid accuracy: 0.802
# Epoch 7/20.. Train loss: 1.701.. valid loss: 0.805.. valid accuracy: 0.794
# Epoch 7/20.. Train loss: 1.867.. valid loss: 0.840.. valid accuracy: 0.791
# Epoch 7/20.. Train loss: 1.841.. valid loss: 0.846.. valid accuracy: 0.789
# Epoch 7/20.. Train loss: 1.898.. valid loss: 0.844.. valid accuracy: 0.783
# Epoch 7/20.. Train loss: 1.886.. valid loss: 0.830.. valid accuracy: 0.799
# Epoch 7/20.. Train loss: 1.824.. valid loss: 0.788.. valid accuracy: 0.809
# Epoch 7/20.. Train loss: 1.923.. valid loss: 0.826.. valid accuracy: 0.797
# Epoch 7/20.. Train loss: 2.013.. valid loss: 0.811.. valid accuracy: 0.804
# Epoch 7/20.. Train loss: 2.040.. valid loss: 0.778.. valid accuracy: 0.813
# Epoch 7/20.. Train loss: 1.984.. valid loss: 0.778.. valid accuracy: 0.817
# Epoch 7/20.. Train loss: 1.776.. valid loss: 0.822.. valid accuracy: 0.809
# Epoch 7/20.. Train loss: 1.910.. valid loss: 0.847.. valid accuracy: 0.799
# Epoch 7/20.. Train loss: 1.777.. valid loss: 0.870.. valid accuracy: 0.802
# Epoch 7/20.. Train loss: 1.797.. valid loss: 0.851.. valid accuracy: 0.797
# Epoch 7/20.. Train loss: 2.075.. valid loss: 0.804.. valid accuracy: 0.805
# Epoch 8/20.. Train loss: 1.872.. valid loss: 0.819.. valid accuracy: 0.794
# Epoch 8/20.. Train loss: 1.980.. valid loss: 0.797.. valid accuracy: 0.812
# Epoch 8/20.. Train loss: 2.030.. valid loss: 0.816.. valid accuracy: 0.820
# Epoch 8/20.. Train loss: 1.906.. valid loss: 0.792.. valid accuracy: 0.814
# Epoch 8/20.. Train loss: 1.761.. valid loss: 0.761.. valid accuracy: 0.821
# Epoch 8/20.. Train loss: 1.840.. valid loss: 0.797.. valid accuracy: 0.810
# Epoch 8/20.. Train loss: 1.754.. valid loss: 0.797.. valid accuracy: 0.808
# Epoch 8/20.. Train loss: 1.723.. valid loss: 0.789.. valid accuracy: 0.817
# Epoch 8/20.. Train loss: 2.012.. valid loss: 0.798.. valid accuracy: 0.813
# Epoch 8/20.. Train loss: 1.918.. valid loss: 0.792.. valid accuracy: 0.797
# Epoch 8/20.. Train loss: 2.081.. valid loss: 0.791.. valid accuracy: 0.810
# Epoch 8/20.. Train loss: 1.946.. valid loss: 0.796.. valid accuracy: 0.817
# Epoch 8/20.. Train loss: 1.814.. valid loss: 0.803.. valid accuracy: 0.815
# Epoch 8/20.. Train loss: 2.062.. valid loss: 0.780.. valid accuracy: 0.815
# Epoch 8/20.. Train loss: 1.789.. valid loss: 0.754.. valid accuracy: 0.842
# Epoch 8/20.. Train loss: 1.718.. valid loss: 0.745.. valid accuracy: 0.834
# Epoch 8/20.. Train loss: 1.675.. valid loss: 0.781.. valid accuracy: 0.824
# Epoch 8/20.. Train loss: 1.895.. valid loss: 0.786.. valid accuracy: 0.818
# Epoch 8/20.. Train loss: 1.806.. valid loss: 0.802.. valid accuracy: 0.826
# Epoch 8/20.. Train loss: 1.972.. valid loss: 0.792.. valid accuracy: 0.820
# Epoch 9/20.. Train loss: 2.029.. valid loss: 0.792.. valid accuracy: 0.828
# Epoch 9/20.. Train loss: 1.709.. valid loss: 0.835.. valid accuracy: 0.811
# Epoch 9/20.. Train loss: 2.064.. valid loss: 0.833.. valid accuracy: 0.804
# Epoch 9/20.. Train loss: 1.745.. valid loss: 0.833.. valid accuracy: 0.796
# Epoch 9/20.. Train loss: 1.980.. valid loss: 0.792.. valid accuracy: 0.805
# Epoch 9/20.. Train loss: 2.133.. valid loss: 0.844.. valid accuracy: 0.807
# Epoch 9/20.. Train loss: 1.755.. valid loss: 0.916.. valid accuracy: 0.784
# Epoch 9/20.. Train loss: 1.654.. valid loss: 0.911.. valid accuracy: 0.784
# Epoch 9/20.. Train loss: 1.723.. valid loss: 0.878.. valid accuracy: 0.783
# Epoch 9/20.. Train loss: 1.909.. valid loss: 0.836.. valid accuracy: 0.802
# Epoch 9/20.. Train loss: 1.722.. valid loss: 0.849.. valid accuracy: 0.805
# Epoch 9/20.. Train loss: 1.959.. valid loss: 0.881.. valid accuracy: 0.793
# Epoch 9/20.. Train loss: 2.049.. valid loss: 0.847.. valid accuracy: 0.823
# Epoch 9/20.. Train loss: 1.866.. valid loss: 0.835.. valid accuracy: 0.820
# Epoch 9/20.. Train loss: 1.798.. valid loss: 0.816.. valid accuracy: 0.818
# Epoch 9/20.. Train loss: 1.822.. valid loss: 0.773.. valid accuracy: 0.825
# Epoch 9/20.. Train loss: 1.983.. valid loss: 0.775.. valid accuracy: 0.816
# Epoch 9/20.. Train loss: 2.090.. valid loss: 0.791.. valid accuracy: 0.818
# Epoch 9/20.. Train loss: 2.126.. valid loss: 0.793.. valid accuracy: 0.827
# Epoch 9/20.. Train loss: 1.840.. valid loss: 0.824.. valid accuracy: 0.801
# Epoch 9/20.. Train loss: 1.828.. valid loss: 0.781.. valid accuracy: 0.790
# Epoch 10/20.. Train loss: 1.633.. valid loss: 0.736.. valid accuracy: 0.820
# Epoch 10/20.. Train loss: 1.830.. valid loss: 0.763.. valid accuracy: 0.808
# Epoch 10/20.. Train loss: 1.723.. valid loss: 0.778.. valid accuracy: 0.808
# Epoch 10/20.. Train loss: 1.832.. valid loss: 0.776.. valid accuracy: 0.810
# Epoch 10/20.. Train loss: 1.847.. valid loss: 0.768.. valid accuracy: 0.818
# Epoch 10/20.. Train loss: 1.862.. valid loss: 0.766.. valid accuracy: 0.827
# Epoch 10/20.. Train loss: 1.928.. valid loss: 0.785.. valid accuracy: 0.816
# Epoch 10/20.. Train loss: 2.119.. valid loss: 0.847.. valid accuracy: 0.805
# Epoch 10/20.. Train loss: 1.776.. valid loss: 0.830.. valid accuracy: 0.794
# Epoch 10/20.. Train loss: 1.715.. valid loss: 0.813.. valid accuracy: 0.828
# Epoch 10/20.. Train loss: 1.888.. valid loss: 0.819.. valid accuracy: 0.827
# Epoch 10/20.. Train loss: 2.097.. valid loss: 0.831.. valid accuracy: 0.815
# Epoch 10/20.. Train loss: 1.838.. valid loss: 0.825.. valid accuracy: 0.814
# Epoch 10/20.. Train loss: 2.148.. valid loss: 0.799.. valid accuracy: 0.840
# Epoch 10/20.. Train loss: 2.018.. valid loss: 0.815.. valid accuracy: 0.840
# Epoch 10/20.. Train loss: 1.856.. valid loss: 0.830.. valid accuracy: 0.844
# Epoch 10/20.. Train loss: 1.756.. valid loss: 0.830.. valid accuracy: 0.833
# Epoch 10/20.. Train loss: 1.944.. valid loss: 0.821.. valid accuracy: 0.829
# Epoch 10/20.. Train loss: 1.740.. valid loss: 0.847.. valid accuracy: 0.819
# Epoch 10/20.. Train loss: 1.951.. valid loss: 0.823.. valid accuracy: 0.816
# Epoch 10/20.. Train loss: 1.875.. valid loss: 0.803.. valid accuracy: 0.823
# Epoch 11/20.. Train loss: 1.620.. valid loss: 0.822.. valid accuracy: 0.809
# Epoch 11/20.. Train loss: 1.763.. valid loss: 0.843.. valid accuracy: 0.811
# Epoch 11/20.. Train loss: 1.865.. valid loss: 0.831.. valid accuracy: 0.818
# Epoch 11/20.. Train loss: 1.604.. valid loss: 0.821.. valid accuracy: 0.806
# Epoch 11/20.. Train loss: 1.804.. valid loss: 0.793.. valid accuracy: 0.808
# Epoch 11/20.. Train loss: 1.819.. valid loss: 0.755.. valid accuracy: 0.833
# Epoch 11/20.. Train loss: 1.612.. valid loss: 0.733.. valid accuracy: 0.838
# Epoch 11/20.. Train loss: 1.789.. valid loss: 0.752.. valid accuracy: 0.836
# Epoch 11/20.. Train loss: 1.523.. valid loss: 0.779.. valid accuracy: 0.822
# Epoch 11/20.. Train loss: 1.843.. valid loss: 0.785.. valid accuracy: 0.828
# Epoch 11/20.. Train loss: 1.626.. valid loss: 0.775.. valid accuracy: 0.822
# Epoch 11/20.. Train loss: 1.792.. valid loss: 0.781.. valid accuracy: 0.815
# Epoch 11/20.. Train loss: 2.086.. valid loss: 0.803.. valid accuracy: 0.814
# Epoch 11/20.. Train loss: 1.816.. valid loss: 0.774.. valid accuracy: 0.823
# Epoch 11/20.. Train loss: 1.616.. valid loss: 0.761.. valid accuracy: 0.821
# Epoch 11/20.. Train loss: 1.848.. valid loss: 0.747.. valid accuracy: 0.824
# Epoch 11/20.. Train loss: 1.805.. valid loss: 0.753.. valid accuracy: 0.819
# Epoch 11/20.. Train loss: 2.090.. valid loss: 0.805.. valid accuracy: 0.796
# Epoch 11/20.. Train loss: 2.135.. valid loss: 0.764.. valid accuracy: 0.817
# Epoch 11/20.. Train loss: 1.868.. valid loss: 0.788.. valid accuracy: 0.824
# Epoch 12/20.. Train loss: 1.698.. valid loss: 0.794.. valid accuracy: 0.835
# Epoch 12/20.. Train loss: 1.771.. valid loss: 0.752.. valid accuracy: 0.844
# Epoch 12/20.. Train loss: 1.768.. valid loss: 0.741.. valid accuracy: 0.830
# Epoch 12/20.. Train loss: 1.913.. valid loss: 0.728.. valid accuracy: 0.836
# Epoch 12/20.. Train loss: 1.738.. valid loss: 0.708.. valid accuracy: 0.842
# Epoch 12/20.. Train loss: 1.765.. valid loss: 0.732.. valid accuracy: 0.832
# Epoch 12/20.. Train loss: 1.934.. valid loss: 0.752.. valid accuracy: 0.837
# Epoch 12/20.. Train loss: 1.798.. valid loss: 0.782.. valid accuracy: 0.824
# Epoch 12/20.. Train loss: 1.849.. valid loss: 0.779.. valid accuracy: 0.829
# Epoch 12/20.. Train loss: 1.733.. valid loss: 0.775.. valid accuracy: 0.822
# Epoch 12/20.. Train loss: 1.888.. valid loss: 0.766.. valid accuracy: 0.819
# Epoch 12/20.. Train loss: 2.067.. valid loss: 0.743.. valid accuracy: 0.819
# Epoch 12/20.. Train loss: 1.847.. valid loss: 0.783.. valid accuracy: 0.822
# Epoch 12/20.. Train loss: 1.722.. valid loss: 0.797.. valid accuracy: 0.826
# Epoch 12/20.. Train loss: 1.635.. valid loss: 0.799.. valid accuracy: 0.821
# Epoch 12/20.. Train loss: 1.991.. valid loss: 0.770.. valid accuracy: 0.824
# Epoch 12/20.. Train loss: 2.302.. valid loss: 0.743.. valid accuracy: 0.835
# Epoch 12/20.. Train loss: 1.936.. valid loss: 0.778.. valid accuracy: 0.831
# Epoch 12/20.. Train loss: 1.688.. valid loss: 0.819.. valid accuracy: 0.823
# Epoch 12/20.. Train loss: 1.706.. valid loss: 0.818.. valid accuracy: 0.826
# Epoch 12/20.. Train loss: 1.709.. valid loss: 0.826.. valid accuracy: 0.836
# Epoch 13/20.. Train loss: 1.727.. valid loss: 0.795.. valid accuracy: 0.845
# Epoch 13/20.. Train loss: 1.722.. valid loss: 0.757.. valid accuracy: 0.850
# Epoch 13/20.. Train loss: 1.964.. valid loss: 0.727.. valid accuracy: 0.842
# Epoch 13/20.. Train loss: 1.853.. valid loss: 0.733.. valid accuracy: 0.849
# Epoch 13/20.. Train loss: 1.898.. valid loss: 0.768.. valid accuracy: 0.830
# Epoch 13/20.. Train loss: 1.781.. valid loss: 0.786.. valid accuracy: 0.836
# Epoch 13/20.. Train loss: 1.806.. valid loss: 0.776.. valid accuracy: 0.837
# Epoch 13/20.. Train loss: 1.759.. valid loss: 0.756.. valid accuracy: 0.854
# Epoch 13/20.. Train loss: 1.703.. valid loss: 0.744.. valid accuracy: 0.842
# Epoch 13/20.. Train loss: 1.633.. valid loss: 0.730.. valid accuracy: 0.837
# Epoch 13/20.. Train loss: 1.761.. valid loss: 0.726.. valid accuracy: 0.834
# Epoch 13/20.. Train loss: 1.744.. valid loss: 0.716.. valid accuracy: 0.841
# Epoch 13/20.. Train loss: 1.728.. valid loss: 0.713.. valid accuracy: 0.847
# Epoch 13/20.. Train loss: 1.814.. valid loss: 0.730.. valid accuracy: 0.842
# Epoch 13/20.. Train loss: 2.182.. valid loss: 0.789.. valid accuracy: 0.835
# Epoch 13/20.. Train loss: 1.675.. valid loss: 0.818.. valid accuracy: 0.830
# Epoch 13/20.. Train loss: 1.674.. valid loss: 0.810.. valid accuracy: 0.823
# Epoch 13/20.. Train loss: 1.894.. valid loss: 0.800.. valid accuracy: 0.833
# Epoch 13/20.. Train loss: 1.624.. valid loss: 0.788.. valid accuracy: 0.825
# Epoch 13/20.. Train loss: 1.838.. valid loss: 0.802.. valid accuracy: 0.815
# Epoch 14/20.. Train loss: 1.949.. valid loss: 0.820.. valid accuracy: 0.819
# Epoch 14/20.. Train loss: 1.789.. valid loss: 0.838.. valid accuracy: 0.820
# Epoch 14/20.. Train loss: 1.887.. valid loss: 0.860.. valid accuracy: 0.816
# Epoch 14/20.. Train loss: 1.946.. valid loss: 0.904.. valid accuracy: 0.824
# Epoch 14/20.. Train loss: 1.706.. valid loss: 0.850.. valid accuracy: 0.829
# Epoch 14/20.. Train loss: 1.869.. valid loss: 0.775.. valid accuracy: 0.827
# Epoch 14/20.. Train loss: 1.855.. valid loss: 0.725.. valid accuracy: 0.852
# Epoch 14/20.. Train loss: 1.584.. valid loss: 0.721.. valid accuracy: 0.845
# Epoch 14/20.. Train loss: 1.847.. valid loss: 0.744.. valid accuracy: 0.851
# Epoch 14/20.. Train loss: 2.161.. valid loss: 0.767.. valid accuracy: 0.844
# Epoch 14/20.. Train loss: 1.888.. valid loss: 0.763.. valid accuracy: 0.833
# Epoch 14/20.. Train loss: 1.682.. valid loss: 0.745.. valid accuracy: 0.824
# Epoch 14/20.. Train loss: 1.822.. valid loss: 0.751.. valid accuracy: 0.836
# Epoch 14/20.. Train loss: 1.672.. valid loss: 0.764.. valid accuracy: 0.839
# Epoch 14/20.. Train loss: 1.669.. valid loss: 0.725.. valid accuracy: 0.852
# Epoch 14/20.. Train loss: 1.694.. valid loss: 0.698.. valid accuracy: 0.848
# Epoch 14/20.. Train loss: 2.016.. valid loss: 0.697.. valid accuracy: 0.853
# Epoch 14/20.. Train loss: 1.750.. valid loss: 0.721.. valid accuracy: 0.848
# Epoch 14/20.. Train loss: 1.730.. valid loss: 0.759.. valid accuracy: 0.846
# Epoch 14/20.. Train loss: 1.675.. valid loss: 0.762.. valid accuracy: 0.845
# Epoch 14/20.. Train loss: 1.675.. valid loss: 0.734.. valid accuracy: 0.843
# Epoch 15/20.. Train loss: 1.628.. valid loss: 0.713.. valid accuracy: 0.835
# Epoch 15/20.. Train loss: 1.518.. valid loss: 0.724.. valid accuracy: 0.827
# Epoch 15/20.. Train loss: 1.891.. valid loss: 0.712.. valid accuracy: 0.833
# Epoch 15/20.. Train loss: 1.785.. valid loss: 0.676.. valid accuracy: 0.855
# Epoch 15/20.. Train loss: 1.769.. valid loss: 0.673.. valid accuracy: 0.861
# Epoch 15/20.. Train loss: 1.563.. valid loss: 0.681.. valid accuracy: 0.866
# Epoch 15/20.. Train loss: 1.989.. valid loss: 0.709.. valid accuracy: 0.846
# Epoch 15/20.. Train loss: 1.753.. valid loss: 0.726.. valid accuracy: 0.852
# Epoch 15/20.. Train loss: 1.644.. valid loss: 0.738.. valid accuracy: 0.843
# Epoch 15/20.. Train loss: 1.592.. valid loss: 0.714.. valid accuracy: 0.857
# Epoch 15/20.. Train loss: 1.751.. valid loss: 0.708.. valid accuracy: 0.860
# Epoch 15/20.. Train loss: 1.951.. valid loss: 0.728.. valid accuracy: 0.855
# Epoch 15/20.. Train loss: 1.663.. valid loss: 0.736.. valid accuracy: 0.849
# Epoch 15/20.. Train loss: 1.773.. valid loss: 0.719.. valid accuracy: 0.839
# Epoch 15/20.. Train loss: 1.861.. valid loss: 0.710.. valid accuracy: 0.837
# Epoch 15/20.. Train loss: 1.757.. valid loss: 0.712.. valid accuracy: 0.838
# Epoch 15/20.. Train loss: 1.665.. valid loss: 0.729.. valid accuracy: 0.847
# Epoch 15/20.. Train loss: 1.834.. valid loss: 0.724.. valid accuracy: 0.841
# Epoch 15/20.. Train loss: 2.104.. valid loss: 0.712.. valid accuracy: 0.860
# Epoch 15/20.. Train loss: 1.521.. valid loss: 0.704.. valid accuracy: 0.859
# Epoch 15/20.. Train loss: 1.849.. valid loss: 0.714.. valid accuracy: 0.853
# Epoch 16/20.. Train loss: 1.650.. valid loss: 0.749.. valid accuracy: 0.831
# Epoch 16/20.. Train loss: 1.656.. valid loss: 0.778.. valid accuracy: 0.830
# Epoch 16/20.. Train loss: 1.579.. valid loss: 0.771.. valid accuracy: 0.827
# Epoch 16/20.. Train loss: 1.794.. valid loss: 0.752.. valid accuracy: 0.853
# Epoch 16/20.. Train loss: 1.622.. valid loss: 0.717.. valid accuracy: 0.873
# Epoch 16/20.. Train loss: 1.771.. valid loss: 0.692.. valid accuracy: 0.875
# Epoch 16/20.. Train loss: 1.770.. valid loss: 0.680.. valid accuracy: 0.864
# Epoch 16/20.. Train loss: 1.766.. valid loss: 0.677.. valid accuracy: 0.869
# Epoch 16/20.. Train loss: 1.689.. valid loss: 0.705.. valid accuracy: 0.849
# Epoch 16/20.. Train loss: 1.832.. valid loss: 0.711.. valid accuracy: 0.853
# Epoch 16/20.. Train loss: 1.635.. valid loss: 0.726.. valid accuracy: 0.851
# Epoch 16/20.. Train loss: 1.597.. valid loss: 0.755.. valid accuracy: 0.839
# Epoch 16/20.. Train loss: 1.896.. valid loss: 0.782.. valid accuracy: 0.836
# Epoch 16/20.. Train loss: 1.676.. valid loss: 0.787.. valid accuracy: 0.837
# Epoch 16/20.. Train loss: 1.662.. valid loss: 0.761.. valid accuracy: 0.843
# Epoch 16/20.. Train loss: 1.745.. valid loss: 0.749.. valid accuracy: 0.850
# Epoch 16/20.. Train loss: 1.710.. valid loss: 0.736.. valid accuracy: 0.844
# Epoch 16/20.. Train loss: 1.778.. valid loss: 0.713.. valid accuracy: 0.842
# Epoch 16/20.. Train loss: 1.484.. valid loss: 0.709.. valid accuracy: 0.846
# Epoch 16/20.. Train loss: 1.522.. valid loss: 0.711.. valid accuracy: 0.848
# Epoch 17/20.. Train loss: 1.806.. valid loss: 0.721.. valid accuracy: 0.857
# Epoch 17/20.. Train loss: 1.600.. valid loss: 0.727.. valid accuracy: 0.833
# Epoch 17/20.. Train loss: 1.613.. valid loss: 0.730.. valid accuracy: 0.837
# Epoch 17/20.. Train loss: 1.688.. valid loss: 0.743.. valid accuracy: 0.832
# Epoch 17/20.. Train loss: 1.798.. valid loss: 0.730.. valid accuracy: 0.830
# Epoch 17/20.. Train loss: 1.848.. valid loss: 0.725.. valid accuracy: 0.831
# Epoch 17/20.. Train loss: 1.697.. valid loss: 0.741.. valid accuracy: 0.840
# Epoch 17/20.. Train loss: 1.621.. valid loss: 0.762.. valid accuracy: 0.837
# Epoch 17/20.. Train loss: 1.838.. valid loss: 0.757.. valid accuracy: 0.852
# Epoch 17/20.. Train loss: 1.603.. valid loss: 0.750.. valid accuracy: 0.854
# Epoch 17/20.. Train loss: 1.993.. valid loss: 0.738.. valid accuracy: 0.855
# Epoch 17/20.. Train loss: 1.929.. valid loss: 0.715.. valid accuracy: 0.862
# Epoch 17/20.. Train loss: 1.883.. valid loss: 0.710.. valid accuracy: 0.860
# Epoch 17/20.. Train loss: 1.867.. valid loss: 0.734.. valid accuracy: 0.853
# Epoch 17/20.. Train loss: 1.708.. valid loss: 0.729.. valid accuracy: 0.851
# Epoch 17/20.. Train loss: 1.781.. valid loss: 0.707.. valid accuracy: 0.860
# Epoch 17/20.. Train loss: 1.586.. valid loss: 0.735.. valid accuracy: 0.852
# Epoch 17/20.. Train loss: 1.606.. valid loss: 0.734.. valid accuracy: 0.853
# Epoch 17/20.. Train loss: 1.908.. valid loss: 0.722.. valid accuracy: 0.861
# Epoch 17/20.. Train loss: 1.790.. valid loss: 0.738.. valid accuracy: 0.858
# Epoch 17/20.. Train loss: 1.743.. valid loss: 0.762.. valid accuracy: 0.853
# Epoch 18/20.. Train loss: 1.558.. valid loss: 0.767.. valid accuracy: 0.852
# Epoch 18/20.. Train loss: 1.812.. valid loss: 0.761.. valid accuracy: 0.837
# Epoch 18/20.. Train loss: 1.968.. valid loss: 0.762.. valid accuracy: 0.826
# Epoch 18/20.. Train loss: 1.578.. valid loss: 0.763.. valid accuracy: 0.828
# Epoch 18/20.. Train loss: 1.808.. valid loss: 0.776.. valid accuracy: 0.824
# Epoch 18/20.. Train loss: 1.505.. valid loss: 0.737.. valid accuracy: 0.842
# Epoch 18/20.. Train loss: 1.605.. valid loss: 0.729.. valid accuracy: 0.841
# Epoch 18/20.. Train loss: 1.843.. valid loss: 0.748.. valid accuracy: 0.842
# Epoch 18/20.. Train loss: 1.520.. valid loss: 0.762.. valid accuracy: 0.851
# Epoch 18/20.. Train loss: 1.617.. valid loss: 0.744.. valid accuracy: 0.855
# Epoch 18/20.. Train loss: 1.709.. valid loss: 0.740.. valid accuracy: 0.855
# Epoch 18/20.. Train loss: 1.890.. valid loss: 0.742.. valid accuracy: 0.867
# Epoch 18/20.. Train loss: 1.653.. valid loss: 0.760.. valid accuracy: 0.857
# Epoch 18/20.. Train loss: 1.663.. valid loss: 0.756.. valid accuracy: 0.853
# Epoch 18/20.. Train loss: 1.769.. valid loss: 0.745.. valid accuracy: 0.843
# Epoch 18/20.. Train loss: 1.987.. valid loss: 0.752.. valid accuracy: 0.832
# Epoch 18/20.. Train loss: 1.762.. valid loss: 0.761.. valid accuracy: 0.841
# Epoch 18/20.. Train loss: 1.513.. valid loss: 0.768.. valid accuracy: 0.837
# Epoch 18/20.. Train loss: 1.771.. valid loss: 0.766.. valid accuracy: 0.841
# Epoch 18/20.. Train loss: 1.778.. valid loss: 0.776.. valid accuracy: 0.843
# Epoch 19/20.. Train loss: 2.025.. valid loss: 0.794.. valid accuracy: 0.843
# Epoch 19/20.. Train loss: 1.690.. valid loss: 0.787.. valid accuracy: 0.848
# Epoch 19/20.. Train loss: 1.619.. valid loss: 0.759.. valid accuracy: 0.845
# Epoch 19/20.. Train loss: 1.554.. valid loss: 0.749.. valid accuracy: 0.841
# Epoch 19/20.. Train loss: 1.892.. valid loss: 0.739.. valid accuracy: 0.837
# Epoch 19/20.. Train loss: 1.745.. valid loss: 0.711.. valid accuracy: 0.835
# Epoch 19/20.. Train loss: 1.771.. valid loss: 0.683.. valid accuracy: 0.847
# Epoch 19/20.. Train loss: 1.816.. valid loss: 0.682.. valid accuracy: 0.860
# Epoch 19/20.. Train loss: 1.835.. valid loss: 0.682.. valid accuracy: 0.863
# Epoch 19/20.. Train loss: 1.811.. valid loss: 0.707.. valid accuracy: 0.854
# Epoch 19/20.. Train loss: 1.565.. valid loss: 0.694.. valid accuracy: 0.860
# Epoch 19/20.. Train loss: 1.773.. valid loss: 0.717.. valid accuracy: 0.854
# Epoch 19/20.. Train loss: 1.551.. valid loss: 0.729.. valid accuracy: 0.850
# Epoch 19/20.. Train loss: 2.164.. valid loss: 0.736.. valid accuracy: 0.839
# Epoch 19/20.. Train loss: 1.961.. valid loss: 0.745.. valid accuracy: 0.837
# Epoch 19/20.. Train loss: 1.603.. valid loss: 0.733.. valid accuracy: 0.849
# Epoch 19/20.. Train loss: 1.457.. valid loss: 0.706.. valid accuracy: 0.862
# Epoch 19/20.. Train loss: 1.699.. valid loss: 0.681.. valid accuracy: 0.865
# Epoch 19/20.. Train loss: 1.665.. valid loss: 0.660.. valid accuracy: 0.872
# Epoch 19/20.. Train loss: 1.818.. valid loss: 0.666.. valid accuracy: 0.868
# Epoch 19/20.. Train loss: 1.767.. valid loss: 0.694.. valid accuracy: 0.859
# Epoch 20/20.. Train loss: 1.611.. valid loss: 0.715.. valid accuracy: 0.862
# Epoch 20/20.. Train loss: 1.974.. valid loss: 0.704.. valid accuracy: 0.867
# Epoch 20/20.. Train loss: 1.772.. valid loss: 0.710.. valid accuracy: 0.858
# Epoch 20/20.. Train loss: 1.667.. valid loss: 0.731.. valid accuracy: 0.844
# Epoch 20/20.. Train loss: 1.962.. valid loss: 0.753.. valid accuracy: 0.840
# Epoch 20/20.. Train loss: 1.913.. valid loss: 0.762.. valid accuracy: 0.855
# Epoch 20/20.. Train loss: 1.779.. valid loss: 0.750.. valid accuracy: 0.855
# Epoch 20/20.. Train loss: 1.810.. valid loss: 0.755.. valid accuracy: 0.849
# Epoch 20/20.. Train loss: 2.025.. valid loss: 0.747.. valid accuracy: 0.859
# Epoch 20/20.. Train loss: 1.810.. valid loss: 0.758.. valid accuracy: 0.847
# Epoch 20/20.. Train loss: 1.848.. valid loss: 0.766.. valid accuracy: 0.847
# Epoch 20/20.. Train loss: 1.595.. valid loss: 0.767.. valid accuracy: 0.836
# Epoch 20/20.. Train loss: 1.661.. valid loss: 0.747.. valid accuracy: 0.844
# Epoch 20/20.. Train loss: 1.781.. valid loss: 0.718.. valid accuracy: 0.848
# Epoch 20/20.. Train loss: 1.752.. valid loss: 0.698.. valid accuracy: 0.853
# Epoch 20/20.. Train loss: 1.722.. valid loss: 0.685.. valid accuracy: 0.852
# Epoch 20/20.. Train loss: 1.711.. valid loss: 0.679.. valid accuracy: 0.858
# Epoch 20/20.. Train loss: 1.842.. valid loss: 0.667.. valid accuracy: 0.868
# Epoch 20/20.. Train loss: 1.742.. valid loss: 0.673.. valid accuracy: 0.872
# Epoch 20/20.. Train loss: 1.857.. valid loss: 0.675.. valid accuracy: 0.862
# Epoch 20/20.. Train loss: 1.783.. valid loss: 0.675.. valid accuracy: 0.853

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Do validation on the test set
from workspace_utils import active_session
with active_session():
    test_loss = 0
    accuracy = 0
    model.eval()
    with torch.no_grad():
        for inputs, labels in testdataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            logps = model.forward(inputs)
            batch_loss = criterion(logps, labels)

            test_loss += batch_loss.item()

            # Calculate accuracy
            ps = torch.exp(logps)
            top_p, top_class = ps.topk(1, dim=1)
            equals = top_class == labels.view(*top_class.shape)
            accuracy += torch.mean(equals.type(torch.FloatTensor)).item()

        print(f"test loss: {test_loss/len(testdataloader):.3f}.. "
              f"test accuracy: {accuracy/len(testdataloader):.3f}")
# Out:
# test loss: 0.741.. test accuracy: 0.843

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
#cat_to_name_dic = class_to_idx()
checkpoint = {'model': model.state_dict(),
              'optimizer': optimizer.state_dict(),              
              'epoch': epochs,
              'learning_rate': lr,
              'arch': arch,
              'hidden_layers': h_layer,
              'GPU': gpu,               
              'class_to_idx': class_to_idx()
              }

torch.save(checkpoint, 'checkpoint_1.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torchvision
from torchvision import models, transforms, datasets
#import helper

# %%
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model
global class_to_idx
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath)
    arch = checkpoint['arch']
    epochs =checkpoint['epoch']
    lr = checkpoint['learning_rate']
    h_layer= checkpoint['hidden_layers']
    gpu= checkpoint['GPU']
    class_to_idx = checkpoint['class_to_idx']
    
    model= models.vgg16(pretrained = True)

    classifier = nn.Sequential(nn.Linear(25088, h_layer),
                               nn.ReLU(),
                               nn.Dropout(0.5),
                               nn.Linear(h_layer, h_layer),
                               nn.ReLU(),
                               nn.Dropout(0.5),
                               nn.Linear(h_layer, 102),
                               nn.LogSoftmax(dim=1))
    
    model.classifier = classifier
    model.load_state_dict(checkpoint['model'])
    #optimizer.load_state_dict((checkpoint['optimizer']))
    return model 

model = load_checkpoint('checkpoint_1.pth')
model.classifier.state_dict
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.torch/models/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:04<00:00, 113685859.60it/s]
# <bound method Module.state_dict of Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.5)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.5)
#   (6): Linear(in_features=4096, out_features=102, bias=True)
#   (7): LogSoftmax()
# )>

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
import numpy as np
#import helper
from PIL import Image

image_path = test_dir + "/2/image_05100.jpg"
print(image_path)

def process_image(image_path):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''    
    # TODO: Process a PIL image for use in a PyTorch model
    #image_transform = transforms.Compose([transforms.PILToTensor()])
    image_transform = transforms.Compose([transforms.Resize(256),
                                          transforms.CenterCrop(224),
                                          transforms.ToTensor(),
                                          transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
                                      ])

    with Image.open(image_path) as im:
        img_tensor = image_transform(im)
    return img_tensor
# Out:
# flowers/test/2/image_05100.jpg

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.numpy().transpose((1, 2, 0))

    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
img_tensor = process_image(image_path)
#print(type(img_tensor) , img_tensor.shape, image_path)
imshow(img_tensor)#, normalize=True)

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
from os import listdir
import json
        
def class_to_idx():
    # category label to category name mapping
    with open('cat_to_name.json', 'r') as f:
        cat_to_name_dic = json.load(f)
    return cat_to_name_dic

def test_class_to_idex(): #image_dir
    # Retrieve the filenames from folder pet_images/
    class_to_idx_lst = sorted(listdir(test_dir)) 
    test_class_to_idx_dic = {}
    for i in range(len(class_to_idx_lst)):
        test_class_to_idx_dic[i] = class_to_idx_lst[i]
    #print(len(class_to_idx_lst), test_class_to_idx_dic)
    return test_class_to_idx_dic

# %%
def predict(image_path, model, topk=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    '''
    
    # TODO: Implement the code to predict the class from an image file
    img_tensor = process_image(image_path)
    #print(img_tensor.shape)
    # resize the tensor (add dimension for batch)
    img_tensor.unsqueeze_(0)
    #print(img_tensor.shape)
    
    img_tensor.requires_grad_(False)
    
    # puts model in evaluation mode
    model = model.eval()
    
    # apply data to model -
    output = model(img_tensor)
    
    ps = torch.exp(output)
    top_p , top_class = ps.topk(topk, dim=1)
    #print(top_p, top_class)
    
    # return index corresponding to predicted class
    probabilities= top_p[0].detach().numpy()
    top_class_idx = top_class[0].detach().numpy()
    
    # obtain ImageNet labels, category label to category name mapping
    imagenet_classes_dict= class_to_idx()  # image category to image name dictionary
    test_class_to_idx_dict= test_class_to_idex()
    #print(test_class_to_idx_dict[1])

    top_pred_idx = output.data.numpy().argmax()
    top_pred_class= test_class_to_idx_dict[top_pred_idx]
    top_pred_class_name= imagenet_classes_dict[str(top_pred_class)],
    
    top_class_names =[]
    for i in top_class_idx:
        pred_class= test_class_to_idx_dict[i]
        cat =  imagenet_classes_dict[str(pred_class)]
        top_class_names.append(cat)
    top_class_names = np.array(top_class_names)
    return probabilities , top_class_idx,  top_class_names

probabilities ,top_class_idx, top_class_names = predict(image_path, model, 5)
print ("probabilities", probabilities , "top_classes_idx ", top_class_idx , "top_predicted_output ", top_class_names)
# Out:
# probabilities [  1.00000000e+00   2.07925367e-39   3.72033532e-40   1.20796132e-40
#    9.90872157e-41] top_classes_idx  [14  4 77 66 69] top_predicted_output  ['hard-leaved pocket orchid' 'blackberry lily' 'passion flower'
#  'spring crocus' 'moon orchid']

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
plt.figure(1)
img_tensor = process_image(image_path)
imshow(img_tensor)
plt.show()

plt.figure(2)
xlim1 = 0.0
xlim2 = 1.0
#plt.figure(figsize=(8,8))
# Creates axes of plot referenced 'ax'
ax = plt.axes()
# Sets limit for plot for x-axis 
plt.xlim(xlim1, xlim2)
# Set major ticks for x-axis
major_xticks = np.arange(xlim1 , xlim2 , 0.1)
ax.set_xticks(major_xticks)
ax.barh(top_class_names, 100*probabilities, align='center')
ax.set_xlabel('Probability')
ax.set_ylabel('top_class_names')
ax.set_title('classifier output')
plt.show()

# %% [markdown]
# <font color='red'>**Reminder for Workspace users:** If your network becomes very large when saved as a checkpoint, there might be issues with saving backups in your workspace. You should reduce the size of your hidden layers and train again.
#
# We strongly encourage you to delete these large interim files and directories before navigating to another page or closing the browser tab.</font>

# %%
# TODO remove .pth files or move it to a temporary `~/opt` directory in this Workspace
